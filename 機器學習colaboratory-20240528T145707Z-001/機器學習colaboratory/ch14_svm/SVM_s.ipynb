# %% [markdown]
# #SVM(支援向量機，Support Vector Machines)

# %% [markdown]
# ##SVM概念

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##SVM分類

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##SVM 優化
#
# *   有多少錯誤是可以忍受的 (C 較高時，愈不能容忍)
#
# ![image.png](data:image/png;base64,...)
#
#
# *   有多少點被視為獲得決策邊界 (gamma 越高，較近的點被視為獲得決策邊界)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Kernel 函數
#
# 常見的 kernel ：
#
# *   linear 線性
#
# ![image.png](data:image/png;base64,...)
#
# *   Polynomial 高次方轉換
#
# ![image.png](data:image/png;base64,...)
#
# *   Radial Basis Function 高斯轉換
#
# ![image.png](data:image/png;base64,...)
#
#
# 非線性投影(φ)將資料進行轉換到更高維度的空間

# %% [markdown]
# ###polynomial kernel function
#
# 將資料從2維空間轉換到3維空間
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###RBF kernel function
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 泰勒級數展開
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##SVM分類結果

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##鳶尾花_SVM分類

# %%
from sklearn.datasets import load_iris
iris = load_iris()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='linear')

# %%
clf.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
clf.score(X_test,y_test)
# Out:
# 1.0

# %%
clf2=SVC(kernel='rbf')
clf2.fit(X_train,y_train)
clf2.score(X_test,y_test)
# Out:
# 0.9736842105263158

# %%
clf3=SVC(kernel='poly')
clf3.fit(X_train,y_train)
clf3.score(X_test,y_test)
# Out:
# 0.9736842105263158
